# %% [markdown]
# # 1.. What is Context Window (Working Memory analogy)

# %%
'''

Hi there , in this module ,  u will get a deeper understanding How does Brain of Claude actually works !
& it is one of the most imp modules of Claude Code !

    In this module , we will learn : 
        What is Context Window ?
        How to manage context window of Claude and Token usage in Claude ?
        How does Context window of Claude works ?
        Why Context Window matters ? 
        Then
            Some best practises so that u can effectively manage Context Window of Claude
            to get rid of Token usage issue..



So Now lets first understand what a Context Window by using simple Analogy :

"Okay , Let me ask you something…

Have you ever noticed this?

    You ask AI something…
    [Open ChatGPT/gemini/Claude]
        It answers perfectly.

Then after a few messages…

👉 It starts giving weird answers.
    Or completely forgets what you said earlier.

Why does this happen?

    Is AI dumb?
    Ans : No.

    👉 It’s a actually a  limitation.
        This limitation is called: 👉 Context Window

    Now let’s simplify this…
    Think of Claude like a human.

    & we humans have 2 types of memory : 
    🧠 Short-term memory
    🧠 Long-term memory


But Claude(LLMs) ONLY has:
    👉 Short-term memory

    So Context window is like a Model Working Memory !





Just to understand things in more detail , First Understand what is Context ?


[now Notes] from pn 38,  39 , 40 
















'''

# %% [markdown]
# ## 2.. How Context Window of Claude works ?

# %%
'''

Hi there in the last session  , we have leanrnt what a context window of LLMs are in much more depth !
    Now lets understand Context Window of Claude in much more depth : 


[now notes] - pn 41 , 42 , 43 , 44 



'''

# %% [markdown]
# # 3.. Components of Claude Context Window (in detail)

# %%
'''
Hi there in the last session  , we have leanrnt How Context Window of Claude works ?
    Now lets deep dive into components of Claude Context Window !
    
    Okay ,lets first show u something 
    If I go to VSCODE & say :
    /context
    
    This shows all different component that exist in the context window of Claude !
    Now lets understand it one by one !








at pn 45 , 46 , 47 



'''

# %% [markdown]
# # 4.. Auto Compaction

# %%
'''
Hi there ,  now  , lets understand What is Auto Compaction is & How Claude code uses it actually
    to handle Token Usage ?

at pn 47 , 49 , 50 

'''

# %% [markdown]
# # 5.. Why Context Window matters ?

# %%
'''

Hi all , we have learnt what is context window , how to managew tokens , various components of context window 
Now lets talk about "Why Context Window matters ?"

At pm 48 

'''

# %% [markdown]
# # 6.. Good Practises to handle Context Window !

# %%
'''

Hi so now , lets have quick eye on somme Good Practises to handle Context Window



First,
👉 One session per feature
Don’t mix everything in one chat.
Keep one session focused on one task or feature.

Next,
👉 Use /compact
This helps reduce unnecessary context
and keeps your conversation clean and efficient.

Then,
👉 Write focused, polished & specific prompts
The clearer your prompt,
the better the output you’ll get.

And finally,
👉 Use subagents for your work
Instead of doing everything in one place,
break tasks into smaller parts using subagents.

“If you follow these practices,
you’ll get better results, lower cost,
and much cleaner workflows


'''
