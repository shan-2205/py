# %%
'''


background pe : side k chaaro soide claude ka logo type add krot emplate me 


'''

# %%
[Img :

2 bottom arrows 

]

# %% [markdown]
# # 1.. 2 Ways to Use Claude Code !

# %%
'''
Hi there , in this entire module , we will do setup of Claude Code in our system & then we will 
    have hands on as well !
    
See… there are multiple ways to use Claude Code.

    And this is where many beginners get confused.

    They think:
👉 “Which one should I use?”
👉 “Am I doing it the right way?”
    Let’s simplify this completely.

    So there are 2 ways to use Claude Code : 

1.. Via Comamnd Prompt / Terminal or (CLI Mode)
    This is the most raw and powerful way.
    Here You directly interact with Claude Code using commands..
    We will show you how to do it in later session !
    
    & If u want to use Claude at full potential , always use Terminal/Command prompt approach !
    
        👉 So it is basically Best for:
            Advanced users
    
    
2.. 
    You can use Claude Code inside IDE like:

    Visual Studio Code
    PyCharm
    Cursor
    & this approach is Recommended for Beginners , Why?

        let me show u how to use can use calude code inside VSCode which I will show u in the upcmoning 
        sessions  how to do setup & all these things..
        
        You can see your code
        Edit files easily
        Run Python , Java all other scripts
        And u can use Claude side-by-side in your terminal
    
    

& using this Claude code steup in IDE , u can build something real  , real world apps , real world Projects etc..
which we wil discuss in this course !



    
    
    
    


'''

# %% [markdown]
# # 2.. Claude Quick Setup in Terminal !

# %%
[Img :

5 bottom arrows 

]

# %%
'''
at pn 8[b]



Okayy , Before we begin a quick setup of Claude Code , there’s one thing you should know…: 
    Claude is not completely free. , To use the official Claude models,
        you typically need a subscription —
        which is around 20 dollars per month.
    
    
        
        So If you're just starting out, I recommend:

            👉 Go to Claude
            👉 Create an account
            👉 And optionally purchase the monthly plan ($20)

Once you complete the payment and setup…, now lets talk about the Setup of Claude Code !
        
        

🚀 So , These are the simple 5 steps to use Claude Code at your terminal :

1 ) Install git
2 ) Install Claude code
3 ) Run claude code
4 ) Choose login method 
5 ) Run Claude query



Install Git
    If u are Windows User , First u have to install Git in your system
    Bcz Claude internally uses Gitbash to execute commands , thats why
    it needed git in their system !
    
    Do google as : download git for windows
    Download the installer… : & install it by clicking on this .exe file.. then git will be installed in your Windows !
    
    

Install Claude Code
    Do a simple search as : install claude command terminal
            You’ll find an installation command.
            Now here’s important:

            If you’re on Mac → copy Mac command
            If you’re on Windows → copy Windows command
        
            & if U are Windows User , U have to open Command Prompt & paste the command & hit enter !
              if U are Mac User , U have to open terminal & paste the Mac install command & hit enter !
    
    
        It takes couple of mins depending upon internet speed !
        After installation… you’ll see something like:
            ✅ Claude Code successfully installed
        

    
Run Claude
        Run Claude by this command : claude
        
            If u are using Claude for first time , You might see some setup options like theme selection —.

                Just choose what you like & you will be done !
                
        

Choose login method
        Next, Claude will ask you to log in.
            You’ll see multiple options like:
             Select login method:

             > 1. Claude account with subscription · where u can choose your plan(Pro, Max, Team, or Enterprise)
               2. Anthropic Console account · API usage billing
               3. 3rd-party platform
               
               👉 For beginners, choose Option 1, then it will redirect you to calude site to auhtorize it first , 
                Once done , Then come back to terminal… and you’ll see:
                ✅ Login successful 
                
                Login successful. Press Enter to continue…
                
                Press Enter 
                Then it is asking  , do you trust older ,say yes 
                & hit enter !



Run query :  
            Now the fun part…
            Let’s run your first command. : 
            /Models : It shows various Claude models like Opus , Sonnet & haiku !
            
            Lets have simple query to Claude Code like : What is Agentic Ai ?
            U will see its amazing def !
            
            
            now if it looks weird , dont worry in the next session , I will show u real power of Claude Code terminal
            like How u can work on Projects via Claude Code in Terminal 
                    Or
            How u can build some simple Agents for your Projects !
            
            
            
            
            So yeah , Hi , ket me show you the real power of Claude Code in Terminal !
            As Senior developers mostly prefer terminal approach !
            
            Imagine we have this sales data of Amazon !
            
            "So First, we need to move into our project folder so that we can work using Claude Code" !
            
            So lets launch Claude code in terminal !
            Open command prompt & type claude command !
            Just say , I trust it !
            Sounds Okay 
            You will see Current working directory is C drive & we have our Porject in R drive !
            
            so now , I will use cd command , which means : change directory 
            /d allows switching drive + directory together
            
            cd /d "R:\Claude\Files\Sales" : Copy Project folder path which is this one  , & s put it
                Hit Enter & give the permission to claude Code !
                
    
                
                
            
            
            
            Now We have to reference our Project file inside Claude."
            @[mention project file_name]
            @sales_analysis.py : "This @ symbol tells Claude… 👉 ‘Use this file as context’."
            
            and Now let’s ask a simple question :
            
            What the Project is all about ?
            

            Claude Code will reads the entire file & explain this Project !
            saying : Hey , this is a Amazon Sales data analysis project where
           YOu have done all these things like : collect data , clean data & other stuffs !



            Thats power of Claude code , ut can read files form system  , even it can edit those files as per your
            Instruction !
            If this terminal approach looks weird to you , dont worry we will show IDE apporach to 
            use Claude Code & belive it is simple that beginners would love it !


'''

# %% [markdown]
# # 4.. Full Setup of Claude in IDE (VS Code / etc.) !

# %%
'''
at pn 8[b]


We have learnt , compleet setup of Claude cOde via terminal 
Now a lot of beginners don’t like working in terminal… And that’s completely fine.

Because in real-world development…
    👉 Most developers use an IDE like VS Code , Pycharm  , Cursor !

So in this lecture…
    I’ll show you how to use Claude Code directly inside VS Code.





There are the 5 simple steps that we will follow to install claude code in VsCode :

    1 ) Install VSCode
    2 ) Open VScode
    3 ) Install Claude Code 
    4 ) Open a Project Folder/File
    5 ) Run Claude Code



    1 ) Install VSCode
        We will be using VSCode IDE for this course as it is quite beginner friendly !
        Do a google search as : Install VsCode & install right installer as per your OS !
        Select Mac/Windows as per your OS !
        Once done , 
        
    2 ) Open VScode
        Then launch VSCode
        Thats how its UI Looks like !
        
    3 ) Go to Extensions ->> Search Claude here -> Install Claude
        After installing extension:
        You will see icon of Claude code here , this shows Claude Code is integrated in YOur VSCode !
        
        If u are not getting , thats complete;y Okay !
        
        
    
    4 ) Open a Project Folder/File
        Open the Project Folder so that u can use Claude code in this Folder/Project :
        By the way , u can download this Folder from the Lecture itself in zip format !
        So make sure u have extracted that zip file !
        
        lets open this txt file !
        
        
        
    5 ) Run Claude Code
        Before Running Claude Code  , make sure u have installed Git !
        Bcz Claude internally uses Gitbash to execute commands , thats why
        it needed git in their system !
        
        
        Now Click on 3 dots & say Open Claude Code : 
    





'''

# %% [markdown]
# # 5... [Mini Project] : Building Sales Data analysis Project :

# %%
'''
Hi there , in this session… we’re going to do something exciting 🔥
    👉 we will Build a Sales Data Analysis Project using Python

    And don’t worry…
    👉 we’ll keep everything simple + beginner-friendly
    
    Now imagine this… 🤔
    You just joined a company…
    And your manager says:
        👉 “We have sales data… can you find the average sales of our product?”


    So to build this Project , its a simple 3-step process :
    
    1 ) 
        Open the Project Folder/File so that u can use Clude code in this Project :
            👉 Go to :
            File → Open Folder

        
        
    2 ) u have to Launch Claude Code
      & we have already shown you how to install claude code in the earlier session!
        
        
        Now Click on 3 dots & say Open Claude Code : 
    


        
        
     3 ) Give Prompt/Instructions to Claude Code
     
     So that it will read files from this folder , it will rwite python script into file
     & then if error occurs , it will debug it automatically & we have to just review the work !
     
     So our role is more like a : Senior Manager here !
     
     
     
     
        So lets open VSCode !
        Inside Claude panel, 
        Start with a Simple Prompt , :
     Create a Beginner friendly Simple Python script that reads this file 
     'amazon_sales_data.csv' which is at this lovcation of your system @R:\Claude\Files and shows average sales..
     
        

        
        👉 Claude will:
            ask u to read this CSV file
            Write code in python file
            
            7 then it will ask for some basic permissions to to create that file & to put all the codes !
            Now u can see this Python file have been created here as per the tasks u have given !
            
            
            Now u are like a senior manager who have to just review this code & sub,it to your Compnay !
            Thats a real power of Claude code at Enterprise level !
            It will do task end-2-end !
            
          




'''

# %% [markdown]
# # 4.. Free vs Paid Claude Setup (Ollama trick)

# %%
[Img :

2 side arrows  

]

# %%
'''

Hi , in the last session , we have done of Setup of Claude Code in Vs

See Behind the scenes Claude Code uses:
👉 Paid models of anthropic like Opus, Sonnet, Haiku

These are powerful…
But they cost money..



Now here’s the smart trick:

👉 Open-source LLMs locally with Claude Code & thats where U can Use Ollama..
    but LLMs will not be Opus , Sonnet , Haiku..
    By the way , Ollama is a platform where you can run:

    👉 Open-source LLMs locally
    
    
But there’s a tradeoff:

❌ Ollama models will be Slower
❌ Ollama models will be Slightly less powerful

But for learning?

👉 they are Perfect..





Now setup is simple:
    1 ) Install Ollama
        U can Go to Ollama website , 
        copy Command as per Your OS
        
        If u are a Windows User , 
        open Windows Powershell & put this command !
        [irm https://ollama.com/install.ps1 | iex]
        
        It will takes couple of mins as per your system specs & 
        This will download Ollama in your system


    2 ) Now u have to Download Ollama Models locally on your PC
        Ollama Website -> Go to Ollama Models -> Search -> Coding -> Select this model[qwen2.5] as per your system size
        Pls use appropriate model as per your system specs , else it will be nightmare for you !
        
    3 ) To download model , locally into your Pc :
        ollama pull [model_name]
            
    4 ) Connect with Claude Code
            create new session in Vscode terminal
            use this command : Ollama launch claude
            
                Go to + more -> Select model that you already have downloaded !


'''

# %% [markdown]
# # 5.. Bash Mode (Why it matters)
