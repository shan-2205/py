# %% [markdown]
# # 1.. Problem: LLM has no memory !

# %%
'''

Hi there , in this entire module ,, we will deep dive into one of the imp file created by Claude
    that is Claude.md !
    
    First we will understand 
    
    Why there is a need of Claude.md ?
    What is Claude.md ?? 
    /init Command
    What Claude.md actually have



So Imagine this…

You spend 2 hours building something with AI…
let say : You are a Data Analyst at Uber & your Job is to Analyze Uber Ride data !

You’ve already done a lot:

    Collected Uber data from various sources
    Cleaned messy data
    Built KPIs (Total rides, Peak hours , Revenue per trip)
    Built dashboards [show dashbaord] so that u can showcase it to managers 
    
    And not just that…

    👉 You even created insights like:

        “Most rides happen between 6 PM – 9 PM”
        “Airport routes generate higher revenue”
        “Weekend demand is 30% higher”

Everything is working perfectly.
You’re confident.
You’re proud..





Now next day… Your Manager says to improve this dashbaord
Then You open a new AI session.
And you say:
    👉 “Help me improve my Uber analysis dashboard”

And suddenly…
The claude Code asks:

    👉 “What does your dataset look like?”
    👉 “What columns are available?”
    👉 “How are you calculating revenue?”
                OR May be :
    Claude may generate Wrong code



And you’re like…
😩 “I already explained all of this yesterday!”

So its Frustrating… right?

[Pause]



👉 Bcz LLMs like Claude don’t have memory across sessions..
    LLMs are memory-less / stateless 
            OR
    Claude don’t remember anything across sessions.

They only remember what’s inside the current conversation/session..
And this creates a HUGE problem…






So the real question is…

👉 How do we make Claude REMEMBER our project?"
    One way is : Explain things from scratch into every new session ( thats practically impossibe 
                    in bigger projects)
                    
    Second way is : You could give AI one file… & that file contains all your
                    Project info 
                    And then  , Claude understands your entire project instantly 
                    & that file is known as Claude.md !




'''

# %% [markdown]
# # 2.. What is Claude.md ?

# %%
'''


Claude.md se arrow below me :

    
    Project Purpose
    Project Architecture
    Dataset Overview
    Tools & technologies 
    

'''

# %%
'''

Hi in the last session , we have learnt that when we create new sessions/conversations ,
    LLMs doesn't remember anything , bcz they dont have memory !
    & this will create a problem when working on projects !



So now the question is…

👉 How do we make Claude REMEMBER our project?"
    One way is : Explain things from scratch into every new session ( thats practically impossibe 
                    in bigger projects)
                    Bcz in bigge projects , u could have Millions of lines of Code , 100s of files !
                    
                    
    Second way is : You could give AI one file… & that file contains all your
                    Project info :
                    
                    [What is Dataset structure (ride_id, pickup_time, fare, location) , 
                    What are the various Data cleaning steps
                    Feature engineering logic (peak hours, surge pricing)
                    Key insights you already discovered
                    ]
                    
                    And then , Claude understands your entire project instantly 
                    & that file is known as Claude.md !
                    👉 So Claude simply reads this file …and instantly understands your entire project..
                    
                    👉So Claude.md is basically a memory file for your Uber data project.
                                    OR
                       Claude.md = rule-book + Summary of your Project for AI
                                                   [which tells Claude :
                                                       What your Project is all about :
                                                       How your Code is structured
                                                       What tools & Libraries u are suing in your Project]

'''

# %% [markdown]
# # 3.. /init Command Deep Dive

# %%
'''
Hi so now , lets talk about various ways to create Claude.md file !

In egenral there are 2 ways to create : 


At PN no : [54 , 55 , 56]

'''

# %% [markdown]
# # 4.. What Claude.md actually have

# %%
'''


Hi  , sor far , we have learnt what is Claude.md file  , how to create that file as well !
Now lets deep dive into what this file actually contains !


at Pn no [57 , 58 , 59]


'''

# %% [markdown]
# # 🎯 Task : Create Claude.md for sample project
