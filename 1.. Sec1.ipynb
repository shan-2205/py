# %% [markdown]
# # 1.. Welcome & What You’ll Build :

# %%
'''

Hi there , in this course , we will learn Claude Code from complete beginner…
    to someone who can actually use Claude Code like a pro..
    so that you can build Agents & Automate Your workflows !


    First, we’ll build a strong foundation.

    You’ll understand:

        The Claude ecosystem (so you don’t get confused)
        How Claude actually works behind the scenes
        
    Then we’ll go deeper…
    Where You’ll learn powerful concepts of Claude like:

        How to manage the context window
        How to create agents and sub-agents
        How to use the Claude.md file
        
   And also…

        Auto compaction
        Auto memory
        Skills, MCP, rules

All the core concepts…
then we will Build Real-World Projects :

Where You’ll learn how to:

    👉 Build AI agents using Claude Code 10X faster 
    👉 Automate coding tasks
    👉 Work on real-world use cases

    


'''

# %% [markdown]
# # 3.. What is Claude Code (Simple Explanation)

# %%
show Image already : Claud code = LLM + Tools

# %%
'''
Hi there , now lets understand what exactly is Claude Code?
    In layman terms : It’s an agent built on top of an LLM
    
Think of it like this 👇
At the core, there is an LLM — a large language model.

You can think of it as:

🧠 The brain

Now, here’s the important part…
    A brain alone can think…
    but it cannot actually do anything in the real world.
    Right?

It can’t open files
It can’t write code in your system
It can’t run commands


So the question is…

👉 How do we make this brain actually useful?

    That’s where Tools come in.
    When we connect this brain to tools…
    Now everything changes..
    
    because using Tools , now it can:

✅ Read files from your computer using File Reading Tool
✅ It can Write code for your Project using Code Writing Tool
✅ It can Run commands using Terminal / Bash Tool
✅ It can search the entire Internet using Web Search Tool
    Like You say:
    “Find latest Python version and update my code as per latest version”
    
    Claude:
    Searches web using Web search Tool
    & Updates your code accordingly
    

    So u can say :
    
    Without tools → Claude can only talks
    With tools → Claude works like a Programmer / developer / Data Scientist / AI Eng 


So if I simplify everything into one powerful line:

👉 Claude Code = Brain (LLM) + Tools (Action Layer)




'''

# %%
'''


Show:


Imagine You have recently Joined Amazon/Youtube as Data Analyst
    It’s your Day 1.
    You’re excited… but also a little nervous.
    
    And then your manager tells you:  👉 “Can you give me a summary of this project?”
    [show Files]
    
    Now think about it…
        This project has:
        Multiple files
        Millions of lines of code
        Different modules
        Unknown logic 
        
    So what would you normally do?
    You start opening files one by one…
        trying to understand the code…
        reading documentation…

        But It can easily take… : 👉 1 to 2 days
    
    But now… let’s use Claude Code.  , You simply open the project…
    and give one powerful prompt:
    Dont worry I will explain you how to do all these things in this course !
    
    
    So your prompt is : "Give all the tasks that we have done in this Project"
    
        And within seconds…
        Claude will:

            Analyze your entire codebase
            Understand the logic
            Identify key functionalities
            And generate a clean summary
    
🎯 That’s the real power of Claude Code
    It doesn’t just help you write code…

👉 It helps you understand entire systems instantly.

    
    And in this course..
    we’re going to use this same power…
    to actually build things faster than ever before.


'''

# %%
'''


🎥 Demo Instructions:

Split screen:
Left → Traditional coding (typing manually)
Right → Claude generating code
Show time difference
Say:
"This is the shift."


'''

# %% [markdown]
# # 4.. AI Coding vs Traditional Coding !

# %%
'''
Hi there , now lets understand what is simple diff between Traditional Coding vs AI-assisted Coding !

"SO Let’s be honest for a moment…

If I ask : How do most people code today?
    So : 
    They open their IDE to write code
    They Write code line by line…
    They Debug errors…
    They Google solutions…
    Repeat…

That’s traditional coding where People do all the code in a manual way..

And it works.
But it’s slow.



Now compare that with this…

You describe what you want…
    👉 AI builds it for you.

    You guide…
    👉 AI executes.
    This is AI-assisted codingor often known as Agentic Coding !

And here’s the biggest mindset shift…



👉 You are no longer just a coder
👉 You become a Senior Manager where u give some instructiosn to do task 

You don’t do everything manually anymore.

Instead:

✅ You give instructions to do some task
✅ You review output
✅ You improve results

That’s why productivity becomes:
    👉 10x faster

And output quality becomes
    👉 Often better.
    
    and the whole world is experiencing same thing , thats why Industry is changing & companies
    are forcing people to do AI-Assisted coding..
    
    
    Thats where its important to master such tools like : Claude



'''

# %% [markdown]
# # 🎯 Mini Task (End of Section)

# %%
'''


"Before moving ahead…

I don’t want you to do anything.

No coding.
No setup.

Just observe things..
Think about it : 

👉 How AI is writing code
👉 How fast things are happening
👉 What your role could be



Because curiosity is the first step.

In the next section…

We’ll turn this curiosity…

👉 Into real skills."


'''
