# %% [markdown]
# # 1.. What we are building ?

# %%
'''

"Alright, before we jump into Project… let’s understand what we’re building.

    We are creating a Code Debugger Agent using Claude Code that will :
                
    👉 Understand your code , scan your entire Codebase , all the functions , all the folders
    👉 Find errors in our code 
    👉 Explan the issue
    👉 Return fixed code
    👉 Update Fixed Code in the file as well



"Now you might be thinking…
    Why is this important?"

In real-world development:

    Developers/Programmers spend 30–40% time debugging
    Companies use AI tools to reduce debugging time
    Tools like GitHub Copilot, Cursor, etc. are doing similar things

So what you’re building today…

👉 is a mini version of real AI developer tools
    And this is EXACTLY how AI Engineers think."



    So in short , we are building an agent , which will scan our entire codebase , all the files  , find bugs in our code
    & veen update those files as well !
    & this is one of the real world challenge which we will solve it by building an Coding Dubugging Agent using Claude code !



'''

# %% [markdown]
# # 2.. Setup

# %%
'''


"Alright, let’s set up our environment.

Since we are using Claude Code via VS Code terminal…
we don’t need anything complex.

We need VSCode , Python & claude Code terminal tahts it !



so launch the VS Code !
make sure Python is installed ( u can go to extensions here & install Python from here )
& amke sure Claude Code is working in your terminal

Now Open Project via VSCode !
    By the way , u can download this from resources as well !
    
    
& in this test.txt : Manager have given us Python script to debug it !    
    Now let’s create a simple file : debug.py"
    .py means : Its a Python file & lets put all this script here !
            
            First Let me explain what the code is in simple terms :
            
            
            
            
            
            
            '''




            Imports pandas library to work with data
            Reads the CSV file using pandas read_csv function and stores file into variable called df
            Then we will clean the data like : we Removes duplicate rows from the dataset
                
            ## then we have to enture data-types are correct !    
            So first we will Converts Quantity column to integer data type
            Then Converts Price column to float (decimal) type
            
            
            ## Then we will Creates a new column Total_Sales by multiplying Quantity and Price
                so that we wil analyse which is the highest selling product !
            
            
            ## so to find Total_Sales of every product , 
            first Groups rows of data by product name & compute total quantities of every product ,
            & then sort it to find top-selling products..
            
            & then we will Displays the product with highest total quantity sold so call head(1) , print the
                first row !


'''

# %% [markdown]
# # 3.. Prompt Enginnering basics !

# %%
'''


"Hi there… So far, we have completed the entire setup of our project.
And now… comes the most exciting part…

👉 & This is where the MAGIC happens."

We need to tell Claude to find the error in code & fix that..

Remember — Claude is powerful…
            but only if you give it the RIGHT instructions.
            It means we have to write effective prompt :
            
           So now , 

            we will Give precise instructions to claude
            So that Claude Uses fewer tokens & returns clean & usable output


This is called 👉 Prompt Engineering." 


            So let’s write our first debugging prompt."

    & dont worry , I will explain you every component of prompt that I am going to write !
    
💻 What to Show:

Inside terminal (Claude Code):
Paste:


You are an expert Python debugger.
Fix the error in the currently open file.

Tasks:
1. Correct the code
2. Explain the error clearly in 1-2 lines
3. Apply the fix directly to the file



[show img]


"First component is 👉 Context (Role)

    This tells AI… WHO it should behave like."

    ✅ In YOUR Prompt:
    "Here we are telling Claude…

    👉 Don’t act like a general AI
    👉 Act like a Python debugging expert

    And this dramatically improves output quality."
    
    
    
    
"Second is 👉 Instruction

    This tells AI exactly WHAT to do."

    ✅ In YOUR Prompt:
    Fix the error in the currently open file.

    👉 No confusion
    👉 No ambiguity

    That’s why Claude directly starts debugging."
    
    
    
    
    
"Third component is 👉 Input Data

    This is the information AI uses to solve the problem."

    ✅ In YOUR Case:
    👉 The currently open file (sales.py) si the Input data..



    👉 Claude automatically reads the file
    That means…
    👉 The file itself becomes the INPUT."





"Fourth is 👉 Output Indicator

    This tells AI HOW to respond."

    ✅ In YOUR Prompt:
    Tasks:
        1. Correct the code
        2. Explain the error clearly in 1-2 lines
        3. Apply the fix directly to the file


    👉 Without this, output might becomes messy

    👉 With this, output becomes structured and predictable"
    
    
🧠 Break it down:
    Context → Expert debugger
    Instruction → Fix the error
    Input → Current file
    Output → Structured tasks
    
    
    So once I send this prompt to Claude , Claude will debug code very efficiently & thats what we will do in the 
    next session !
    
    


'''

# %% [markdown]
# # 4.. Debugging using Claude !

# %%
'''



Alright w ehave defined efective prompt & When u hit enter !


    Claude starts analyzing your entire codebase , all the files,  folders
    & now Claude is asking permission to acess the files !
    Just say , yes I am giving permission to Claude code to access all the folders,  files !
    
    Once u give permission , then it will find the error in code & it is aking again to update your file
     , so give permssion & now u will observe your code gets corrected !


     it is saying that : these are basically typos u have done in your code !
                     
                     




now If I execute this entire updated code , now this is working correctly & returning you Top selling product !
This sounds interesting !


& And this is exactly how AI agents debug code."
"They:

    👉 Read your code
    👉 Understand the problem
    👉 Fix it
    👉 And update it automatically"



So yeah Congratulations — you have just built first real AI Agent workflow!



'''
